# %%
# !jar xvf images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  inflated: images/Rottweiler/n02106550_107.jpg
#  inflated: images/Rottweiler/n02106550_10706.jpg
#  inflated: images/Rottweiler/n02106550_10709.jpg
#  inflated: images/Rottweiler/n02106550_10714.jpg
#  inflated: images/Rottweiler/n02106550_10952.jpg
#  inflated: images/Rottweiler/n02106550_10966.jpg
#  inflated: images/Rottweiler/n02106550_11002.jpg
#  inflated: images/Rottweiler/n02106550_11097.jpg
#  inflated: images/Rottweiler/n02106550_11105.jpg
#  inflated: images/Rottweiler/n02106550_11176.jpg
#  inflated: images/Rottweiler/n02106550_11203.jpg
#  inflated: images/Rottweiler/n02106550_11244.jpg
#  inflated: images/Rottweiler/n02106550_11323.jpg
#  inflated: images/Rottweiler/n02106550_11354.jpg
#  inflated: images/Rottweiler/n02106550_11415.jpg
#  inflated: images/Rottweiler/n02106550_11433.jpg
#  inflated: images/Rottweiler/n02106550_11444.jpg
#  inflated: images/Rottweiler/n02106550_11465.jpg
#  inflated: images/Rottweiler/n02106550_11543.jpg
#  inflated: images/Rottweiler/n02106550_11564.jpg
#  inflated: images/Rottweiler/n02106550_11693.jpg
#  inflated: images/Rottweiler/n02106550_11728.jpg
#  inflated: images/Rottweiler/n02106550_11762.jpg
#  inflated: images/Rottweiler/n02106550_11823.jpg
#  inflated: images/Rottweiler/n02106550_11870.jpg
#  inflated: images/Rottweiler/n02106550_11903.jpg
#  inflated: images/Rottweiler/n02106550_12073.jpg
#  inflated: images/Rottweiler/n02106550_12129.jpg
#  inflated: images/Rottweiler/n02106550_12160.jpg
#  inflated: images/Rottweiler/n02106550_12409.jpg
#  inflated: images/Rottweiler/n02106550_12424.jpg
#  inflated: images/Rottweiler/n02106550_12438.jpg
#  inflated: images/Rottweiler/n02106550_1260.jpg
#  inflated: images/Rottweiler/n02106550_12642.jpg
#  inflated: images/Rottweiler/n02106550_12760.jpg
#  inflated: images/Rottweiler/n02106550_12828.jpg
#  inflated: images/Rottweiler/n02106550_12948.jpg
#  inflated: images/Rottweiler/n02106550_13034.jpg
#  inflated: images/Rottweiler/n02106550_13213.jpg
#  inflated: images/Rottweiler/n02106550_13226.jpg
#  inflated: images/Rottweiler/n02106550_1323.jpg
#  inflated: images/Rottweiler/n02106550_1366.jpg
#  inflated: images/Rottweiler/n02106550_1388.jpg
#  inflated: images/Rottweiler/n02106550_148.jpg
#  inflated: images/Rottweiler/n02106550_1567.jpg
#  inflated: images/Rottweiler/n02106550_1591.jpg
#  inflated: images/Rottweiler/n02106550_1742.jpg
#  inflated: images/Rottweiler/n02106550_1889.jpg
#  inflated: images/Rottweiler/n02106550_193.jpg
#  inflated: images/Rottweiler/n02106550_1974.jpg
#  inflated: images/Rottweiler/n02106550_2052.jpg
#  inflated: images/Rottweiler/n02106550_208.jpg
#  inflated: images/Rottweiler/n02106550_2082.jpg
#  inflated: images/Rottweiler/n02106550_2197.jpg
#  inflated: images/Rottweiler/n02106550_2301.jpg
#  inflated: images/Rottweiler/n02106550_2323.jpg
#  inflated: images/Rottweiler/n02106550_2725.jpg
#  inflated: images/Rottweiler/n02106550_2832.jpg
#  inflated: images/Rottweiler/n02106550_2862.jpg
#  inflated: images/Rottweiler/n02106550_3237.jpg
#  inflated: images/Rottweiler/n02106550_3313.jpg
#  inflated: images/Rottweiler/n02106550_3524.jpg
#  inflated: images/Rottweiler/n02106550_3528.jpg
#  inflated: images/Rottweiler/n02106550_3610.jpg
#  inflated: images/Rottweiler/n02106550_3886.jpg
#  inflated: images/Rottweiler/n02106550_3930.jpg
#  inflated: images/Rottweiler/n02106550_3931.jpg
#  inflated: images/Rottweiler/n02106550_3969.jpg
#  inflated: images/Rottweiler/n02106550_3993.jpg
#  inflated: images/Rottweiler/n02106550_4039.jpg
#  inflated: images/Rottweiler/n02106550_4063.jpg
#  inflated: images/Rottweiler/n02106550_4072.jpg
#  inflated: images/Rottweiler/n02106550_4079.jpg
#  inflated: images/Rottweiler/n02106550_4129.jpg
#  inflated: images/Rottweiler/n02106550_4138.jpg
#  inflated: images/Rottweiler/n02106550_4150.jpg
#  inflated: images/Rottweiler/n02106550_4191.jpg
#  inflated: images/Rottweiler/n02106550_4217.jpg
#  inflated: images/Rottweiler/n02106550_4239.jpg
#  inflated: images/Rottweiler/n02106550_4254.jpg
#  inflated: images/Rottweiler/n02106550_4339.jpg
#  inflated: images/Rottweiler/n02106550_4397.jpg
#  inflated: images/Rottweiler/n02106550_4785.jpg
#  inflated: images/Rottweiler/n02106550_4910.jpg
#  inflated: images/Rottweiler/n02106550_4920.jpg
#  inflated: images/Rottweiler/n02106550_4955.jpg
#  inflated: images/Rottweiler/n02106550_4962.jpg
#  inflated: images/Rottweiler/n02106550_4987.jpg
#  inflated: images/Rottweiler/n02106550_5028.jpg
#  inflated: images/Rottweiler/n02106550_5133.jpg
#  inflated: images/Rottweiler/n02106550_5184.jpg
#  inflated: images/Rottweiler/n02106550_5222.jpg
#  inflated: images/Rottweiler/n02106550_5252.jpg
#  inflated: images/Rottweiler/n02106550_5271.jpg
#  inflated: images/Rottweiler/n02106550_5311.jpg
#  inflated: images/Rottweiler/n02106550_5710.jpg
#  inflated: images/Rottweiler/n02106550_5752.jpg
#  inflated: images/Rottweiler/n02106550_5754.jpg
#  inflated: images/Rottweiler/n02106550_5928.jpg
#  inflated: images/Rottweiler/n02106550_6074.jpg
#  inflated: images/Rottweiler/n02106550_6130.jpg
#  inflated: images/Rottweiler/n02106550_6192.jpg
#  inflated: images/Rottweiler/n02106550_6272.jpg
#  inflated: images/Rottweiler/n02106550_6286.jpg
#  inflated: images/Rottweiler/n02106550_6310.jpg
#  inflated: images/Rottweiler/n02106550_6402.jpg
#  inflated: images/Rottweiler/n02106550_6424.jpg
#  inflated: images/Rottweiler/n02106550_6599.jpg
#  inflated: images/Rottweiler/n02106550_6900.jpg
#  inflated: images/Rottweiler/n02106550_6910.jpg
#  inflated: images/Rottweiler/n02106550_6926.jpg
#  inflated: images/Rottweiler/n02106550_6965.jpg
#  inflated: images/Rottweiler/n02106550_6978.jpg
#  inflated: images/Rottweiler/n02106550_7003.jpg
#  inflated: images/Rottweiler/n02106550_7393.jpg
#  inflated: images/Rottweiler/n02106550_7419.jpg
#  inflated: images/Rottweiler/n02106550_7430.jpg
#  inflated: images/Rottweiler/n02106550_7473.jpg
#  inflated: images/Rottweiler/n02106550_7608.jpg
#  inflated: images/Rottweiler/n02106550_7616.jpg
#  inflated: images/Rottweiler/n02106550_7767.jpg
#  inflated: images/Rottweiler/n02106550_8024.jpg
#  inflated: images/Rottweiler/n02106550_8064.jpg
#  inflated: images/Rottweiler/n02106550_8116.jpg
#  inflated: images/Rottweiler/n02106550_8146.jpg
#  inflated: images/Rottweiler/n02106550_8166.jpg
#  inflated: images/Rottweiler/n02106550_8383.jpg
#  inflated: images/Rottweiler/n02106550_8437.jpg
#  inflated: images/Rottweiler/n02106550_8595.jpg
#  inflated: images/Rottweiler/n02106550_8611.jpg
#  inflated: images/Rottweiler/n02106550_8652.jpg
#  inflated: images/Rottweiler/n02106550_8776.jpg
#  inflated: images/Rottweiler/n02106550_8887.jpg
#  inflated: images/Rottweiler/n02106550_895.jpg
#  inflated: images/Rottweiler/n02106550_8994.jpg
#  inflated: images/Rottweiler/n02106550_9084.jpg
#  inflated: images/Rottweiler/n02106550_9317.jpg
#  inflated: images/Rottweiler/n02106550_9348.jpg
#  inflated: images/Rottweiler/n02106550_9432.jpg
#  inflated: images/Rottweiler/n02106550_9508.jpg
#  inflated: images/Rottweiler/n02106550_982.jpg
#   created: images/Saint_Bernard/
#  inflated: images/Saint_Bernard/n02109525_10032.jpg
#  inflated: images/Saint_Bernard/n02109525_10063.jpg
#  inflated: images/Saint_Bernard/n02109525_10146.jpg
#  inflated: images/Saint_Bernard/n02109525_10215.jpg
#  inflated: images/Saint_Bernard/n02109525_10251.jpg
#  inflated: images/Saint_Bernard/n02109525_10297.jpg
#  inflated: images/Saint_Bernard/n02109525_10321.jpg
#  inflated: images/Saint_Bernard/n02109525_10332.jpg
#  inflated: images/Saint_Bernard/n02109525_10374.jpg
#  inflated: images/Saint_Bernard/n02109525_10417.jpg
#  inflated: images/Saint_Bernard/n02109525_10446.jpg
#  inflated: images/Saint_Bernard/n02109525_10545.jpg
#  inflated: images/Saint_Bernard/n02109525_10743.jpg
#  inflated: images/Saint_Bernard/n02109525_10792.jpg
#  inflated: images/Saint_Bernard/n02109525_10805.jpg
#  inflated: images/Saint_Bernard/n02109525_10908.jpg
#  inflated: images/Saint_Bernard/n02109525_10960.jpg
#  inflated: images/Saint_Bernard/n02109525_10992.jpg
#  inflated: images/Saint_Bernard/n02109525_1100.jpg
#  inflated: images/Saint_Bernard/n02109525_11155.jpg
#  inflated: images/Saint_Bernard/n02109525_11274.jpg
#  inflated: images/Saint_Bernard/n02109525_11285.jpg
#  inflated: images/Saint_Bernard/n02109525_11444.jpg
#  inflated: images/Saint_Bernard/n02109525_11445.jpg
#  inflated: images/Saint_Bernard/n02109525_11452.jpg
#  inflated: images/Saint_Bernard/n02109525_11465.jpg
#  inflated: images/Saint_Bernard/n02109525_11732.jpg
#  inflated: images/Saint_Bernard/n02109525_11747.jpg
#  inflated: images/Saint_Bernard/n02109525_12041.jpg
#  inflated: images/Saint_Bernard/n02109525_12155.jpg
#  inflated: images/Saint_Bernard/n02109525_12272.jpg
#  inflated: images/Saint_Bernard/n02109525_12392.jpg
#  inflated: images/Saint_Bernard/n02109525_12604.jpg
#  inflated: images/Saint_Bernard/n02109525_12610.jpg
#  inflated: images/Saint_Bernard/n02109525_12641.jpg
#  inflated: images/Saint_Bernard/n02109525_1271.jpg
#  inflated: images/Saint_Bernard/n02109525_12736.jpg
#  inflated: images/Saint_Bernard/n02109525_12875.jpg
#  inflated: images/Saint_Bernard/n02109525_12937.jpg
#  inflated: images/Saint_Bernard/n02109525_1314.jpg
#  inflated: images/Saint_Bernard/n02109525_13146.jpg
#  inflated: images/Saint_Bernard/n02109525_13154.jpg
#  inflated: images/Saint_Bernard/n02109525_13230.jpg
#  inflated: images/Saint_Bernard/n02109525_13356.jpg
#  inflated: images/Saint_Bernard/n02109525_13410.jpg
#  inflated: images/Saint_Bernard/n02109525_13420.jpg
#  inflated: images/Saint_Bernard/n02109525_13580.jpg
#  inflated: images/Saint_Bernard/n02109525_13627.jpg
#  inflated: images/Saint_Bernard/n02109525_13655.jpg
#  inflated: images/Saint_Bernard/n02109525_13702.jpg
#  inflated: images/Saint_Bernard/n02109525_13780.jpg
#  inflated: images/Saint_Bernard/n02109525_13794.jpg
#  inflated: images/Saint_Bernard/n02109525_13804.jpg
#  inflated: images/Saint_Bernard/n02109525_13812.jpg
#  inflated: images/Saint_Bernard/n02109525_13906.jpg
#  inflated: images/Saint_Bernard/n02109525_13988.jpg
#  inflated: images/Saint_Bernard/n02109525_14198.jpg
#  inflated: images/Saint_Bernard/n02109525_14249.jpg
#  inflated: images/Saint_Bernard/n02109525_14297.jpg
#  inflated: images/Saint_Bernard/n02109525_14676.jpg
#  inflated: images/Saint_Bernard/n02109525_14774.jpg
#  inflated: images/Saint_Bernard/n02109525_1480.jpg
#  inflated: images/Saint_Bernard/n02109525_14999.jpg
#  inflated: images/Saint_Bernard/n02109525_1502.jpg
#  inflated: images/Saint_Bernard/n02109525_15029.jpg
#  inflated: images/Saint_Bernard/n02109525_15376.jpg
#  inflated: images/Saint_Bernard/n02109525_15506.jpg
#  inflated: images/Saint_Bernard/n02109525_15579.jpg
#  inflated: images/Saint_Bernard/n02109525_15746.jpg
#  inflated: images/Saint_Bernard/n02109525_1575.jpg
#  inflated: images/Saint_Bernard/n02109525_16100.jpg
#  inflated: images/Saint_Bernard/n02109525_16215.jpg
#  inflated: images/Saint_Bernard/n02109525_1624.jpg
#  inflated: images/Saint_Bernard/n02109525_16284.jpg
#  inflated: images/Saint_Bernard/n02109525_16346.jpg
#  inflated: images/Saint_Bernard/n02109525_16485.jpg
#  inflated: images/Saint_Bernard/n02109525_16487.jpg
#  inflated: images/Saint_Bernard/n02109525_16981.jpg
#  inflated: images/Saint_Bernard/n02109525_17025.jpg
#  inflated: images/Saint_Bernard/n02109525_17140.jpg
#  inflated: images/Saint_Bernard/n02109525_1717.jpg
#  inflated: images/Saint_Bernard/n02109525_17182.jpg
#  inflated: images/Saint_Bernard/n02109525_17291.jpg
#  inflated: images/Saint_Bernard/n02109525_1741.jpg
#  inflated: images/Saint_Bernard/n02109525_18136.jpg
#  inflated: images/Saint_Bernard/n02109525_18371.jpg
#  inflated: images/Saint_Bernard/n02109525_1843.jpg
#  inflated: images/Saint_Bernard/n02109525_1864.jpg
#  inflated: images/Saint_Bernard/n02109525_18685.jpg
#  inflated: images/Saint_Bernard/n02109525_1880.jpg
#  inflated: images/Saint_Bernard/n02109525_18948.jpg
#  inflated: images/Saint_Bernard/n02109525_1902.jpg
#  inflated: images/Saint_Bernard/n02109525_1972.jpg
#  inflated: images/Saint_Bernard/n02109525_2008.jpg
#  inflated: images/Saint_Bernard/n02109525_2035.jpg
#  inflated: images/Saint_Bernard/n02109525_2104.jpg
#  inflated: images/Saint_Bernard/n02109525_2248.jpg
#  inflated: images/Saint_Bernard/n02109525_2369.jpg
#  inflated: images/Saint_Bernard/n02109525_2385.jpg
#  inflated: images/Saint_Bernard/n02109525_243.jpg
#  inflated: images/Saint_Bernard/n02109525_2575.jpg
#  inflated: images/Saint_Bernard/n02109525_2648.jpg
#  inflated: images/Saint_Bernard/n02109525_2681.jpg
#  inflated: images/Saint_Bernard/n02109525_2737.jpg
#  inflated: images/Saint_Bernard/n02109525_2770.jpg
#  inflated: images/Saint_Bernard/n02109525_2810.jpg
#  inflated: images/Saint_Bernard/n02109525_2840.jpg
#  inflated: images/Saint_Bernard/n02109525_2943.jpg
#  inflated: images/Saint_Bernard/n02109525_3346.jpg
#  inflated: images/Saint_Bernard/n02109525_3360.jpg
#  inflated: images/Saint_Bernard/n02109525_3388.jpg
#  inflated: images/Saint_Bernard/n02109525_3448.jpg
#  inflated: images/Saint_Bernard/n02109525_345.jpg
#  inflated: images/Saint_Bernard/n02109525_3506.jpg
#  inflated: images/Saint_Bernard/n02109525_3531.jpg
#  inflated: images/Saint_Bernard/n02109525_3667.jpg
#  inflated: images/Saint_Bernard/n02109525_368.jpg
#  inflated: images/Saint_Bernard/n02109525_370.jpg
#  inflated: images/Saint_Bernard/n02109525_393.jpg
#  inflated: images/Saint_Bernard/n02109525_4021.jpg
#  inflated: images/Saint_Bernard/n02109525_4308.jpg
#  inflated: images/Saint_Bernard/n02109525_444.jpg
#  inflated: images/Saint_Bernard/n02109525_4516.jpg
#  inflated: images/Saint_Bernard/n02109525_499.jpg
#  inflated: images/Saint_Bernard/n02109525_5007.jpg
#  inflated: images/Saint_Bernard/n02109525_5013.jpg
#  inflated: images/Saint_Bernard/n02109525_523.jpg
#  inflated: images/Saint_Bernard/n02109525_5264.jpg
#  inflated: images/Saint_Bernard/n02109525_5385.jpg
#  inflated: images/Saint_Bernard/n02109525_539.jpg
#  inflated: images/Saint_Bernard/n02109525_5498.jpg
#  inflated: images/Saint_Bernard/n02109525_5966.jpg
#  inflated: images/Saint_Bernard/n02109525_6019.jpg
#  inflated: images/Saint_Bernard/n02109525_6215.jpg
#  inflated: images/Saint_Bernard/n02109525_6593.jpg
#  inflated: images/Saint_Bernard/n02109525_6663.jpg
#  inflated: images/Saint_Bernard/n02109525_6693.jpg
#  inflated: images/Saint_Bernard/n02109525_6931.jpg
#  inflated: images/Saint_Bernard/n02109525_7016.jpg
#  inflated: images/Saint_Bernard/n02109525_7024.jpg
#  inflated: images/Saint_Bernard/n02109525_7085.jpg
#  inflated: images/Saint_Bernard/n02109525_7109.jpg
#  inflated: images/Saint_Bernard/n02109525_7121.jpg
#  inflated: images/Saint_Bernard/n02109525_7336.jpg
#  inflated: images/Saint_Bernard/n02109525_7444.jpg
#  inflated: images/Saint_Bernard/n02109525_7497.jpg
#  inflated: images/Saint_Bernard/n02109525_751.jpg
#  inflated: images/Saint_Bernard/n02109525_7579.jpg
#  inflated: images/Saint_Bernard/n02109525_7656.jpg
#  inflated: images/Saint_Bernard/n02109525_7982.jpg
#  inflated: images/Saint_Bernard/n02109525_8096.jpg
#  inflated: images/Saint_Bernard/n02109525_8211.jpg
#  inflated: images/Saint_Bernard/n02109525_823.jpg
#  inflated: images/Saint_Bernard/n02109525_8312.jpg
#  inflated: images/Saint_Bernard/n02109525_8417.jpg
#  inflated: images/Saint_Bernard/n02109525_8475.jpg
#  inflated: images/Saint_Bernard/n02109525_8545.jpg
#  inflated: images/Saint_Bernard/n02109525_8704.jpg
#  inflated: images/Saint_Bernard/n02109525_8822.jpg
#  inflated: images/Saint_Bernard/n02109525_883.jpg
#  inflated: images/Saint_Bernard/n02109525_9130.jpg
#  inflated: images/Saint_Bernard/n02109525_9243.jpg
#  inflated: images/Saint_Bernard/n02109525_9345.jpg
#  inflated: images/Saint_Bernard/n02109525_9379.jpg
#  inflated: images/Saint_Bernard/n02109525_9426.jpg
#  inflated: images/Saint_Bernard/n02109525_950.jpg
#  inflated: images/Saint_Bernard/n02109525_9522.jpg
#  inflated: images/Saint_Bernard/n02109525_9869.jpg
#  inflated: images/Saint_Bernard/n02109525_9872.jpg
#  inflated: images/Saint_Bernard/n02109525_997.jpg
#   created: images/Saluki/
#  inflated: images/Saluki/n02091831_10215.jpg
#  inflated: images/Saluki/n02091831_10290.jpg
#  inflated: images/Saluki/n02091831_1036.jpg
#  inflated: images/Saluki/n02091831_10576.jpg
#  inflated: images/Saluki/n02091831_10593.jpg
#  inflated: images/Saluki/n02091831_10639.jpg
#  inflated: images/Saluki/n02091831_10722.jpg
#  inflated: images/Saluki/n02091831_10733.jpg
#  inflated: images/Saluki/n02091831_10803.jpg
#  inflated: images/Saluki/n02091831_10822.jpg
#  inflated: images/Saluki/n02091831_10823.jpg
#  inflated: images/Saluki/n02091831_10978.jpg
#  inflated: images/Saluki/n02091831_11021.jpg
#  inflated: images/Saluki/n02091831_1110.jpg
#  inflated: images/Saluki/n02091831_11177.jpg
#  inflated: images/Saluki/n02091831_1118.jpg
#  inflated: images/Saluki/n02091831_11224.jpg
#  inflated: images/Saluki/n02091831_11421.jpg
#  inflated: images/Saluki/n02091831_11498.jpg
#  inflated: images/Saluki/n02091831_11553.jpg
#  inflated: images/Saluki/n02091831_1182.jpg
#  inflated: images/Saluki/n02091831_12653.jpg
#  inflated: images/Saluki/n02091831_12881.jpg
#  inflated: images/Saluki/n02091831_12945.jpg
#  inflated: images/Saluki/n02091831_13354.jpg
#  inflated: images/Saluki/n02091831_13361.jpg
#  inflated: images/Saluki/n02091831_13486.jpg
#  inflated: images/Saluki/n02091831_13507.jpg
#  inflated: images/Saluki/n02091831_13536.jpg
#  inflated: images/Saluki/n02091831_13566.jpg
#  inflated: images/Saluki/n02091831_13640.jpg
#  inflated: images/Saluki/n02091831_13767.jpg
#  inflated: images/Saluki/n02091831_13774.jpg
#  inflated: images/Saluki/n02091831_1387.jpg
#  inflated: images/Saluki/n02091831_13935.jpg
#  inflated: images/Saluki/n02091831_1400.jpg
#  inflated: images/Saluki/n02091831_1439.jpg
#  inflated: images/Saluki/n02091831_1495.jpg
#  inflated: images/Saluki/n02091831_1507.jpg
#  inflated: images/Saluki/n02091831_151.jpg
#  inflated: images/Saluki/n02091831_1512.jpg
#  inflated: images/Saluki/n02091831_1563.jpg
#  inflated: images/Saluki/n02091831_1565.jpg
#  inflated: images/Saluki/n02091831_1594.jpg
#  inflated: images/Saluki/n02091831_1623.jpg
#  inflated: images/Saluki/n02091831_1696.jpg
#  inflated: images/Saluki/n02091831_1730.jpg
#  inflated: images/Saluki/n02091831_1801.jpg
#  inflated: images/Saluki/n02091831_1852.jpg
#  inflated: images/Saluki/n02091831_2076.jpg
#  inflated: images/Saluki/n02091831_2094.jpg
#  inflated: images/Saluki/n02091831_2108.jpg
#  inflated: images/Saluki/n02091831_213.jpg
#  inflated: images/Saluki/n02091831_2232.jpg
#  inflated: images/Saluki/n02091831_2245.jpg
#  inflated: images/Saluki/n02091831_2288.jpg
#  inflated: images/Saluki/n02091831_2290.jpg
#  inflated: images/Saluki/n02091831_2315.jpg
#  inflated: images/Saluki/n02091831_2338.jpg
#  inflated: images/Saluki/n02091831_2344.jpg
#  inflated: images/Saluki/n02091831_2362.jpg
#  inflated: images/Saluki/n02091831_2391.jpg
#  inflated: images/Saluki/n02091831_256.jpg
#  inflated: images/Saluki/n02091831_2586.jpg
#  inflated: images/Saluki/n02091831_2592.jpg
#  inflated: images/Saluki/n02091831_2606.jpg
#  inflated: images/Saluki/n02091831_2638.jpg
#  inflated: images/Saluki/n02091831_2779.jpg
#  inflated: images/Saluki/n02091831_2838.jpg
#  inflated: images/Saluki/n02091831_2858.jpg
#  inflated: images/Saluki/n02091831_2880.jpg
#  inflated: images/Saluki/n02091831_2911.jpg
#  inflated: images/Saluki/n02091831_2962.jpg
#  inflated: images/Saluki/n02091831_2995.jpg
#  inflated: images/Saluki/n02091831_3038.jpg
#  inflated: images/Saluki/n02091831_304.jpg
#  inflated: images/Saluki/n02091831_3042.jpg
#  inflated: images/Saluki/n02091831_3052.jpg
#  inflated: images/Saluki/n02091831_3054.jpg
#  inflated: images/Saluki/n02091831_3061.jpg
#  inflated: images/Saluki/n02091831_3064.jpg
#  inflated: images/Saluki/n02091831_3067.jpg
#  inflated: images/Saluki/n02091831_3108.jpg
#  inflated: images/Saluki/n02091831_3152.jpg
#  inflated: images/Saluki/n02091831_3180.jpg
#  inflated: images/Saluki/n02091831_3222.jpg
#  inflated: images/Saluki/n02091831_3238.jpg
#  inflated: images/Saluki/n02091831_3242.jpg
#  inflated: images/Saluki/n02091831_3254.jpg
#  inflated: images/Saluki/n02091831_3300.jpg
#  inflated: images/Saluki/n02091831_3310.jpg
#  inflated: images/Saluki/n02091831_3334.jpg
#  inflated: images/Saluki/n02091831_3339.jpg
#  inflated: images/Saluki/n02091831_3400.jpg
#  inflated: images/Saluki/n02091831_3430.jpg
#  inflated: images/Saluki/n02091831_3433.jpg
#  inflated: images/Saluki/n02091831_346.jpg
#  inflated: images/Saluki/n02091831_351.jpg
#  inflated: images/Saluki/n02091831_355.jpg
#  inflated: images/Saluki/n02091831_3594.jpg
#  inflated: images/Saluki/n02091831_3616.jpg
#  inflated: images/Saluki/n02091831_3643.jpg
#  inflated: images/Saluki/n02091831_3675.jpg
#  inflated: images/Saluki/n02091831_3760.jpg
#  inflated: images/Saluki/n02091831_3797.jpg
#  inflated: images/Saluki/n02091831_38.jpg
#  inflated: images/Saluki/n02091831_3846.jpg
#  inflated: images/Saluki/n02091831_3847.jpg
#  inflated: images/Saluki/n02091831_3875.jpg
#  inflated: images/Saluki/n02091831_3899.jpg
#  inflated: images/Saluki/n02091831_3909.jpg
#  inflated: images/Saluki/n02091831_3962.jpg
#  inflated: images/Saluki/n02091831_4030.jpg
#  inflated: images/Saluki/n02091831_4057.jpg
#  inflated: images/Saluki/n02091831_4087.jpg
#  inflated: images/Saluki/n02091831_410.jpg
#  inflated: images/Saluki/n02091831_4119.jpg
#  inflated: images/Saluki/n02091831_4142.jpg
#  inflated: images/Saluki/n02091831_4246.jpg
#  inflated: images/Saluki/n02091831_4259.jpg
#  inflated: images/Saluki/n02091831_4283.jpg
#  inflated: images/Saluki/n02091831_4463.jpg
#  inflated: images/Saluki/n02091831_4487.jpg
#  inflated: images/Saluki/n02091831_4626.jpg
#  inflated: images/Saluki/n02091831_4644.jpg
#  inflated: images/Saluki/n02091831_4667.jpg
#  inflated: images/Saluki/n02091831_4755.jpg
#  inflated: images/Saluki/n02091831_4846.jpg
#  inflated: images/Saluki/n02091831_4966.jpg
#  inflated: images/Saluki/n02091831_4980.jpg
#  inflated: images/Saluki/n02091831_5020.jpg
#  inflated: images/Saluki/n02091831_509.jpg
#  inflated: images/Saluki/n02091831_5123.jpg
#  inflated: images/Saluki/n02091831_5216.jpg
#  inflated: images/Saluki/n02091831_5244.jpg
#  inflated: images/Saluki/n02091831_5359.jpg
#  inflated: images/Saluki/n02091831_5369.jpg
#  inflated: images/Saluki/n02091831_5384.jpg
#  inflated: images/Saluki/n02091831_5436.jpg
#  inflated: images/Saluki/n02091831_5482.jpg
#  inflated: images/Saluki/n02091831_55.jpg
#  inflated: images/Saluki/n02091831_5596.jpg
#  inflated: images/Saluki/n02091831_5654.jpg
#  inflated: images/Saluki/n02091831_566.jpg
#  inflated: images/Saluki/n02091831_5692.jpg
#  inflated: images/Saluki/n02091831_5712.jpg
#  inflated: images/Saluki/n02091831_573.jpg
#  inflated: images/Saluki/n02091831_5745.jpg
#  inflated: images/Saluki/n02091831_5879.jpg
#  inflated: images/Saluki/n02091831_6114.jpg
#  inflated: images/Saluki/n02091831_6139.jpg
#  inflated: images/Saluki/n02091831_627.jpg
#  inflated: images/Saluki/n02091831_6308.jpg
#  inflated: images/Saluki/n02091831_6323.jpg
#  inflated: images/Saluki/n02091831_6406.jpg
#  inflated: images/Saluki/n02091831_6427.jpg
#  inflated: images/Saluki/n02091831_6451.jpg
#  inflated: images/Saluki/n02091831_648.jpg
#  inflated: images/Saluki/n02091831_6582.jpg
#  inflated: images/Saluki/n02091831_6757.jpg
#  inflated: images/Saluki/n02091831_699.jpg
#  inflated: images/Saluki/n02091831_7030.jpg
#  inflated: images/Saluki/n02091831_7051.jpg
#  inflated: images/Saluki/n02091831_7066.jpg
#  inflated: images/Saluki/n02091831_7169.jpg
#  inflated: images/Saluki/n02091831_7237.jpg
#  inflated: images/Saluki/n02091831_7244.jpg
#  inflated: images/Saluki/n02091831_725.jpg
#  inflated: images/Saluki/n02091831_7287.jpg
#  inflated: images/Saluki/n02091831_735.jpg
#  inflated: images/Saluki/n02091831_736.jpg
#  inflated: images/Saluki/n02091831_7393.jpg
#  inflated: images/Saluki/n02091831_749.jpg
#  inflated: images/Saluki/n02091831_7497.jpg
#  inflated: images/Saluki/n02091831_764.jpg
#  inflated: images/Saluki/n02091831_7665.jpg
#  inflated: images/Saluki/n02091831_7769.jpg
#  inflated: images/Saluki/n02091831_7846.jpg
#  inflated: images/Saluki/n02091831_7895.jpg
#  inflated: images/Saluki/n02091831_7957.jpg
#  inflated: images/Saluki/n02091831_7977.jpg
#  inflated: images/Saluki/n02091831_801.jpg
#  inflated: images/Saluki/n02091831_8028.jpg
#  inflated: images/Saluki/n02091831_8160.jpg
#  inflated: images/Saluki/n02091831_8223.jpg
#  inflated: images/Saluki/n02091831_8401.jpg
#  inflated: images/Saluki/n02091831_8404.jpg
#  inflated: images/Saluki/n02091831_843.jpg
#  inflated: images/Saluki/n02091831_848.jpg
#  inflated: images/Saluki/n02091831_8633.jpg
#  inflated: images/Saluki/n02091831_878.jpg
#  inflated: images/Saluki/n02091831_8843.jpg
#  inflated: images/Saluki/n02091831_8847.jpg
#  inflated: images/Saluki/n02091831_9190.jpg
#  inflated: images/Saluki/n02091831_9263.jpg
#  inflated: images/Saluki/n02091831_956.jpg
#  inflated: images/Saluki/n02091831_961.jpg
#  inflated: images/Saluki/n02091831_97.jpg
#  inflated: images/Saluki/n02091831_9731.jpg
#  inflated: images/Saluki/n02091831_9856.jpg
#   created: images/Samoyed/
#  inflated: images/Samoyed/n02111889_1.jpg
#  inflated: images/Samoyed/n02111889_10059.jpg
#  inflated: images/Samoyed/n02111889_10084.jpg
#  inflated: images/Samoyed/n02111889_1019.jpg
#  inflated: images/Samoyed/n02111889_1020.jpg
#  inflated: images/Samoyed/n02111889_10206.jpg
#  inflated: images/Samoyed/n02111889_10324.jpg
#  inflated: images/Samoyed/n02111889_10734.jpg
#  inflated: images/Samoyed/n02111889_108.jpg
#  inflated: images/Samoyed/n02111889_10950.jpg
#  inflated: images/Samoyed/n02111889_10987.jpg
#  inflated: images/Samoyed/n02111889_1145.jpg
#  inflated: images/Samoyed/n02111889_11502.jpg
#  inflated: images/Samoyed/n02111889_11729.jpg
#  inflated: images/Samoyed/n02111889_12037.jpg
#  inflated: images/Samoyed/n02111889_12045.jpg
#  inflated: images/Samoyed/n02111889_12073.jpg
#  inflated: images/Samoyed/n02111889_12171.jpg
#  inflated: images/Samoyed/n02111889_12529.jpg
#  inflated: images/Samoyed/n02111889_1255.jpg
#  inflated: images/Samoyed/n02111889_1264.jpg
#  inflated: images/Samoyed/n02111889_12771.jpg
#  inflated: images/Samoyed/n02111889_12811.jpg
#  inflated: images/Samoyed/n02111889_12976.jpg
#  inflated: images/Samoyed/n02111889_1314.jpg
#  inflated: images/Samoyed/n02111889_13281.jpg
#  inflated: images/Samoyed/n02111889_1340.jpg
#  inflated: images/Samoyed/n02111889_13603.jpg
#  inflated: images/Samoyed/n02111889_1363.jpg
#  inflated: images/Samoyed/n02111889_13657.jpg
#  inflated: images/Samoyed/n02111889_13737.jpg
#  inflated: images/Samoyed/n02111889_1374.jpg
#  inflated: images/Samoyed/n02111889_13772.jpg
#  inflated: images/Samoyed/n02111889_13924.jpg
#  inflated: images/Samoyed/n02111889_1402.jpg
#  inflated: images/Samoyed/n02111889_14064.jpg
#  inflated: images/Samoyed/n02111889_1421.jpg
#  inflated: images/Samoyed/n02111889_1438.jpg
#  inflated: images/Samoyed/n02111889_14413.jpg
#  inflated: images/Samoyed/n02111889_1444.jpg
#  inflated: images/Samoyed/n02111889_1451.jpg
#  inflated: images/Samoyed/n02111889_1472.jpg
#  inflated: images/Samoyed/n02111889_14746.jpg
#  inflated: images/Samoyed/n02111889_1485.jpg
#  inflated: images/Samoyed/n02111889_15020.jpg
#  inflated: images/Samoyed/n02111889_15038.jpg
#  inflated: images/Samoyed/n02111889_15299.jpg
#  inflated: images/Samoyed/n02111889_1532.jpg
#  inflated: images/Samoyed/n02111889_15376.jpg
#  inflated: images/Samoyed/n02111889_15388.jpg
#  inflated: images/Samoyed/n02111889_15995.jpg
#  inflated: images/Samoyed/n02111889_16090.jpg
#  inflated: images/Samoyed/n02111889_16116.jpg
#  inflated: images/Samoyed/n02111889_16283.jpg
#  inflated: images/Samoyed/n02111889_16334.jpg
#  inflated: images/Samoyed/n02111889_16414.jpg
#  inflated: images/Samoyed/n02111889_16434.jpg
#  inflated: images/Samoyed/n02111889_16666.jpg
#  inflated: images/Samoyed/n02111889_16676.jpg
#  inflated: images/Samoyed/n02111889_1714.jpg
#  inflated: images/Samoyed/n02111889_1716.jpg
#  inflated: images/Samoyed/n02111889_17192.jpg
#  inflated: images/Samoyed/n02111889_17211.jpg
#  inflated: images/Samoyed/n02111889_1735.jpg
#  inflated: images/Samoyed/n02111889_17368.jpg
#  inflated: images/Samoyed/n02111889_17383.jpg
#  inflated: images/Samoyed/n02111889_1739.jpg
#  inflated: images/Samoyed/n02111889_17532.jpg
#  inflated: images/Samoyed/n02111889_1762.jpg
#  inflated: images/Samoyed/n02111889_17626.jpg
#  inflated: images/Samoyed/n02111889_1772.jpg
#  inflated: images/Samoyed/n02111889_17827.jpg
#  inflated: images/Samoyed/n02111889_18.jpg
#  inflated: images/Samoyed/n02111889_1918.jpg
#  inflated: images/Samoyed/n02111889_1937.jpg
#  inflated: images/Samoyed/n02111889_195.jpg
#  inflated: images/Samoyed/n02111889_1951.jpg
#  inflated: images/Samoyed/n02111889_1968.jpg
#  inflated: images/Samoyed/n02111889_1984.jpg
#  inflated: images/Samoyed/n02111889_1994.jpg
#  inflated: images/Samoyed/n02111889_1995.jpg
#  inflated: images/Samoyed/n02111889_2028.jpg
#  inflated: images/Samoyed/n02111889_2029.jpg
#  inflated: images/Samoyed/n02111889_2030.jpg
#  inflated: images/Samoyed/n02111889_2083.jpg
#  inflated: images/Samoyed/n02111889_2136.jpg
#  inflated: images/Samoyed/n02111889_2186.jpg
#  inflated: images/Samoyed/n02111889_2361.jpg
#  inflated: images/Samoyed/n02111889_2366.jpg
#  inflated: images/Samoyed/n02111889_2410.jpg
#  inflated: images/Samoyed/n02111889_2425.jpg
#  inflated: images/Samoyed/n02111889_2476.jpg
#  inflated: images/Samoyed/n02111889_2544.jpg
#  inflated: images/Samoyed/n02111889_2650.jpg
#  inflated: images/Samoyed/n02111889_2667.jpg
#  inflated: images/Samoyed/n02111889_2677.jpg
#  inflated: images/Samoyed/n02111889_2789.jpg
#  inflated: images/Samoyed/n02111889_2801.jpg
#  inflated: images/Samoyed/n02111889_2820.jpg
#  inflated: images/Samoyed/n02111889_2835.jpg
#  inflated: images/Samoyed/n02111889_2914.jpg
#  inflated: images/Samoyed/n02111889_2947.jpg
#  inflated: images/Samoyed/n02111889_2952.jpg
#  inflated: images/Samoyed/n02111889_3048.jpg
#  inflated: images/Samoyed/n02111889_3221.jpg
#  inflated: images/Samoyed/n02111889_3253.jpg
#  inflated: images/Samoyed/n02111889_3326.jpg
#  inflated: images/Samoyed/n02111889_3345.jpg
#  inflated: images/Samoyed/n02111889_3399.jpg
#  inflated: images/Samoyed/n02111889_3400.jpg
#  inflated: images/Samoyed/n02111889_3409.jpg
#  inflated: images/Samoyed/n02111889_3450.jpg
#  inflated: images/Samoyed/n02111889_3471.jpg
#  inflated: images/Samoyed/n02111889_3476.jpg
#  inflated: images/Samoyed/n02111889_3494.jpg
#  inflated: images/Samoyed/n02111889_3499.jpg
#  inflated: images/Samoyed/n02111889_3566.jpg
#  inflated: images/Samoyed/n02111889_373.jpg
#  inflated: images/Samoyed/n02111889_3918.jpg
#  inflated: images/Samoyed/n02111889_3960.jpg
#  inflated: images/Samoyed/n02111889_3988.jpg
#  inflated: images/Samoyed/n02111889_4027.jpg
#  inflated: images/Samoyed/n02111889_4073.jpg
#  inflated: images/Samoyed/n02111889_4142.jpg
#  inflated: images/Samoyed/n02111889_4147.jpg
#  inflated: images/Samoyed/n02111889_4159.jpg
#  inflated: images/Samoyed/n02111889_4194.jpg
#  inflated: images/Samoyed/n02111889_4353.jpg
#  inflated: images/Samoyed/n02111889_4368.jpg
#  inflated: images/Samoyed/n02111889_4381.jpg
#  inflated: images/Samoyed/n02111889_4408.jpg
#  inflated: images/Samoyed/n02111889_4470.jpg
#  inflated: images/Samoyed/n02111889_4484.jpg
#  inflated: images/Samoyed/n02111889_4588.jpg
#  inflated: images/Samoyed/n02111889_4634.jpg
#  inflated: images/Samoyed/n02111889_464.jpg
#  inflated: images/Samoyed/n02111889_466.jpg
#  inflated: images/Samoyed/n02111889_4679.jpg
#  inflated: images/Samoyed/n02111889_4740.jpg
#  inflated: images/Samoyed/n02111889_475.jpg
#  inflated: images/Samoyed/n02111889_4754.jpg
#  inflated: images/Samoyed/n02111889_4809.jpg
#  inflated: images/Samoyed/n02111889_4950.jpg
#  inflated: images/Samoyed/n02111889_4967.jpg
#  inflated: images/Samoyed/n02111889_5075.jpg
#  inflated: images/Samoyed/n02111889_5121.jpg
#  inflated: images/Samoyed/n02111889_514.jpg
#  inflated: images/Samoyed/n02111889_5145.jpg
#  inflated: images/Samoyed/n02111889_5212.jpg
#  inflated: images/Samoyed/n02111889_5267.jpg
#  inflated: images/Samoyed/n02111889_5452.jpg
#  inflated: images/Samoyed/n02111889_5463.jpg
#  inflated: images/Samoyed/n02111889_5474.jpg
#  inflated: images/Samoyed/n02111889_5489.jpg
#  inflated: images/Samoyed/n02111889_5532.jpg
#  inflated: images/Samoyed/n02111889_5598.jpg
#  inflated: images/Samoyed/n02111889_5602.jpg
#  inflated: images/Samoyed/n02111889_5679.jpg
#  inflated: images/Samoyed/n02111889_5680.jpg
#  inflated: images/Samoyed/n02111889_5738.jpg
#  inflated: images/Samoyed/n02111889_5769.jpg
#  inflated: images/Samoyed/n02111889_5776.jpg
#  inflated: images/Samoyed/n02111889_5778.jpg
#  inflated: images/Samoyed/n02111889_5786.jpg
#  inflated: images/Samoyed/n02111889_5826.jpg
#  inflated: images/Samoyed/n02111889_5932.jpg
#  inflated: images/Samoyed/n02111889_5965.jpg
#  inflated: images/Samoyed/n02111889_597.jpg
#  inflated: images/Samoyed/n02111889_6041.jpg
#  inflated: images/Samoyed/n02111889_6045.jpg
#  inflated: images/Samoyed/n02111889_6076.jpg
#  inflated: images/Samoyed/n02111889_6183.jpg
#  inflated: images/Samoyed/n02111889_6249.jpg
#  inflated: images/Samoyed/n02111889_6333.jpg
#  inflated: images/Samoyed/n02111889_6343.jpg
#  inflated: images/Samoyed/n02111889_6356.jpg
#  inflated: images/Samoyed/n02111889_6376.jpg
#  inflated: images/Samoyed/n02111889_6419.jpg
#  inflated: images/Samoyed/n02111889_6425.jpg
#  inflated: images/Samoyed/n02111889_6512.jpg
#  inflated: images/Samoyed/n02111889_6545.jpg
#  inflated: images/Samoyed/n02111889_6566.jpg
#  inflated: images/Samoyed/n02111889_6592.jpg
#  inflated: images/Samoyed/n02111889_6595.jpg
#  inflated: images/Samoyed/n02111889_662.jpg
#  inflated: images/Samoyed/n02111889_6622.jpg
#  inflated: images/Samoyed/n02111889_6625.jpg
#  inflated: images/Samoyed/n02111889_6631.jpg
#  inflated: images/Samoyed/n02111889_6750.jpg
#  inflated: images/Samoyed/n02111889_6781.jpg
#  inflated: images/Samoyed/n02111889_6811.jpg
#  inflated: images/Samoyed/n02111889_6859.jpg
#  inflated: images/Samoyed/n02111889_691.jpg
#  inflated: images/Samoyed/n02111889_6950.jpg
#  inflated: images/Samoyed/n02111889_6955.jpg
#  inflated: images/Samoyed/n02111889_7002.jpg
#  inflated: images/Samoyed/n02111889_7041.jpg
#  inflated: images/Samoyed/n02111889_7042.jpg
#  inflated: images/Samoyed/n02111889_7049.jpg
#  inflated: images/Samoyed/n02111889_7083.jpg
#  inflated: images/Samoyed/n02111889_7100.jpg
#  inflated: images/Samoyed/n02111889_7207.jpg
#  inflated: images/Samoyed/n02111889_7491.jpg
#  inflated: images/Samoyed/n02111889_771.jpg
#  inflated: images/Samoyed/n02111889_774.jpg
#  inflated: images/Samoyed/n02111889_789.jpg
#  inflated: images/Samoyed/n02111889_8240.jpg
#  inflated: images/Samoyed/n02111889_853.jpg
#  inflated: images/Samoyed/n02111889_8613.jpg
#  inflated: images/Samoyed/n02111889_8626.jpg
#  inflated: images/Samoyed/n02111889_8748.jpg
#  inflated: images/Samoyed/n02111889_8839.jpg
#  inflated: images/Samoyed/n02111889_8870.jpg
#  inflated: images/Samoyed/n02111889_899.jpg
#  inflated: images/Samoyed/n02111889_9001.jpg
#  inflated: images/Samoyed/n02111889_91.jpg
#  inflated: images/Samoyed/n02111889_928.jpg
#  inflated: images/Samoyed/n02111889_9533.jpg
#   created: images/schipperke/
#  inflated: images/schipperke/n02104365_10071.jpg
#  inflated: images/schipperke/n02104365_10139.jpg
#  inflated: images/schipperke/n02104365_10247.jpg
#  inflated: images/schipperke/n02104365_10252.jpg
#  inflated: images/schipperke/n02104365_10282.jpg
#  inflated: images/schipperke/n02104365_10319.jpg
#  inflated: images/schipperke/n02104365_10393.jpg
#  inflated: images/schipperke/n02104365_10399.jpg
#  inflated: images/schipperke/n02104365_10514.jpg
#  inflated: images/schipperke/n02104365_10598.jpg
#  inflated: images/schipperke/n02104365_10606.jpg
#  inflated: images/schipperke/n02104365_10634.jpg
#  inflated: images/schipperke/n02104365_1104.jpg
#  inflated: images/schipperke/n02104365_1151.jpg
#  inflated: images/schipperke/n02104365_1158.jpg
#  inflated: images/schipperke/n02104365_1166.jpg
#  inflated: images/schipperke/n02104365_1292.jpg
#  inflated: images/schipperke/n02104365_1325.jpg
#  inflated: images/schipperke/n02104365_169.jpg
#  inflated: images/schipperke/n02104365_1822.jpg
#  inflated: images/schipperke/n02104365_1837.jpg
#  inflated: images/schipperke/n02104365_1841.jpg
#  inflated: images/schipperke/n02104365_1852.jpg
#  inflated: images/schipperke/n02104365_2031.jpg
#  inflated: images/schipperke/n02104365_2092.jpg
#  inflated: images/schipperke/n02104365_2263.jpg
#  inflated: images/schipperke/n02104365_2424.jpg
#  inflated: images/schipperke/n02104365_2435.jpg
#  inflated: images/schipperke/n02104365_2940.jpg
#  inflated: images/schipperke/n02104365_2978.jpg
#  inflated: images/schipperke/n02104365_2981.jpg
#  inflated: images/schipperke/n02104365_330.jpg
#  inflated: images/schipperke/n02104365_3383.jpg
#  inflated: images/schipperke/n02104365_3587.jpg
#  inflated: images/schipperke/n02104365_3649.jpg
#  inflated: images/schipperke/n02104365_3826.jpg
#  inflated: images/schipperke/n02104365_3950.jpg
#  inflated: images/schipperke/n02104365_3963.jpg
#  inflated: images/schipperke/n02104365_4107.jpg
#  inflated: images/schipperke/n02104365_4190.jpg
#  inflated: images/schipperke/n02104365_4258.jpg
#  inflated: images/schipperke/n02104365_427.jpg
#  inflated: images/schipperke/n02104365_465.jpg
#  inflated: images/schipperke/n02104365_481.jpg
#  inflated: images/schipperke/n02104365_482.jpg
#  inflated: images/schipperke/n02104365_518.jpg
#  inflated: images/schipperke/n02104365_5411.jpg
#  inflated: images/schipperke/n02104365_5551.jpg
#  inflated: images/schipperke/n02104365_5670.jpg
#  inflated: images/schipperke/n02104365_5740.jpg
#  inflated: images/schipperke/n02104365_5781.jpg
#  inflated: images/schipperke/n02104365_5967.jpg
#  inflated: images/schipperke/n02104365_5970.jpg
#  inflated: images/schipperke/n02104365_6131.jpg
#  inflated: images/schipperke/n02104365_6140.jpg
#  inflated: images/schipperke/n02104365_6199.jpg
#  inflated: images/schipperke/n02104365_6291.jpg
#  inflated: images/schipperke/n02104365_6354.jpg
#  inflated: images/schipperke/n02104365_6384.jpg
#  inflated: images/schipperke/n02104365_6395.jpg
#  inflated: images/schipperke/n02104365_6428.jpg
#  inflated: images/schipperke/n02104365_6489.jpg
#  inflated: images/schipperke/n02104365_6498.jpg
#  inflated: images/schipperke/n02104365_6527.jpg
#  inflated: images/schipperke/n02104365_6529.jpg
#  inflated: images/schipperke/n02104365_6551.jpg
#  inflated: images/schipperke/n02104365_6575.jpg
#  inflated: images/schipperke/n02104365_6601.jpg
#  inflated: images/schipperke/n02104365_6625.jpg
#  inflated: images/schipperke/n02104365_663.jpg
#  inflated: images/schipperke/n02104365_6647.jpg
#  inflated: images/schipperke/n02104365_6667.jpg
#  inflated: images/schipperke/n02104365_6693.jpg
#  inflated: images/schipperke/n02104365_67.jpg
#  inflated: images/schipperke/n02104365_6732.jpg
#  inflated: images/schipperke/n02104365_675.jpg
#  inflated: images/schipperke/n02104365_6755.jpg
#  inflated: images/schipperke/n02104365_6798.jpg
#  inflated: images/schipperke/n02104365_6800.jpg
#  inflated: images/schipperke/n02104365_6927.jpg
#  inflated: images/schipperke/n02104365_6930.jpg
#  inflated: images/schipperke/n02104365_7018.jpg
#  inflated: images/schipperke/n02104365_7065.jpg
#  inflated: images/schipperke/n02104365_7158.jpg
#  inflated: images/schipperke/n02104365_725.jpg
#  inflated: images/schipperke/n02104365_729.jpg
#  inflated: images/schipperke/n02104365_7301.jpg
#  inflated: images/schipperke/n02104365_7366.jpg
#  inflated: images/schipperke/n02104365_7368.jpg
#  inflated: images/schipperke/n02104365_7377.jpg
#  inflated: images/schipperke/n02104365_7381.jpg
#  inflated: images/schipperke/n02104365_740.jpg
#  inflated: images/schipperke/n02104365_7409.jpg
#  inflated: images/schipperke/n02104365_7431.jpg
#  inflated: images/schipperke/n02104365_7501.jpg
#  inflated: images/schipperke/n02104365_7518.jpg
#  inflated: images/schipperke/n02104365_7546.jpg
#  inflated: images/schipperke/n02104365_7629.jpg
#  inflated: images/schipperke/n02104365_7641.jpg
#  inflated: images/schipperke/n02104365_7643.jpg
#  inflated: images/schipperke/n02104365_7768.jpg
#  inflated: images/schipperke/n02104365_7791.jpg
#  inflated: images/schipperke/n02104365_7822.jpg
#  inflated: images/schipperke/n02104365_7859.jpg
#  inflated: images/schipperke/n02104365_7881.jpg
#  inflated: images/schipperke/n02104365_7887.jpg
#  inflated: images/schipperke/n02104365_7892.jpg
#  inflated: images/schipperke/n02104365_7906.jpg
#  inflated: images/schipperke/n02104365_7927.jpg
#  inflated: images/schipperke/n02104365_7944.jpg
#  inflated: images/schipperke/n02104365_7953.jpg
#  inflated: images/schipperke/n02104365_7956.jpg
#  inflated: images/schipperke/n02104365_8119.jpg
#  inflated: images/schipperke/n02104365_8156.jpg
#  inflated: images/schipperke/n02104365_8161.jpg
#  inflated: images/schipperke/n02104365_8190.jpg
#  inflated: images/schipperke/n02104365_8226.jpg
#  inflated: images/schipperke/n02104365_8334.jpg
#  inflated: images/schipperke/n02104365_8398.jpg
#  inflated: images/schipperke/n02104365_8451.jpg
#  inflated: images/schipperke/n02104365_8466.jpg
#  inflated: images/schipperke/n02104365_8525.jpg
#  inflated: images/schipperke/n02104365_8548.jpg
#  inflated: images/schipperke/n02104365_8630.jpg
#  inflated: images/schipperke/n02104365_8701.jpg
#  inflated: images/schipperke/n02104365_8706.jpg
#  inflated: images/schipperke/n02104365_8769.jpg
#  inflated: images/schipperke/n02104365_8919.jpg
#  inflated: images/schipperke/n02104365_8998.jpg
#  inflated: images/schipperke/n02104365_9004.jpg
#  inflated: images/schipperke/n02104365_9041.jpg
#  inflated: images/schipperke/n02104365_9131.jpg
#  inflated: images/schipperke/n02104365_9143.jpg
#  inflated: images/schipperke/n02104365_9238.jpg
#  inflated: images/schipperke/n02104365_9248.jpg
#  inflated: images/schipperke/n02104365_9255.jpg
#  inflated: images/schipperke/n02104365_9309.jpg
#  inflated: images/schipperke/n02104365_9337.jpg
#  inflated: images/schipperke/n02104365_9354.jpg
#  inflated: images/schipperke/n02104365_9369.jpg
#  inflated: images/schipperke/n02104365_9399.jpg
#  inflated: images/schipperke/n02104365_9489.jpg
#  inflated: images/schipperke/n02104365_9552.jpg
#  inflated: images/schipperke/n02104365_9595.jpg
#  inflated: images/schipperke/n02104365_9611.jpg
#  inflated: images/schipperke/n02104365_9639.jpg
#  inflated: images/schipperke/n02104365_9640.jpg
#  inflated: images/schipperke/n02104365_9712.jpg
#  inflated: images/schipperke/n02104365_9873.jpg
#  inflated: images/schipperke/n02104365_9916.jpg
#  inflated: images/schipperke/n02104365_9954.jpg
#  inflated: images/schipperke/n02104365_996.jpg
#  inflated: images/schipperke/n02104365_999.jpg
#  inflated: images/schipperke/n02104365_9994.jpg
#   created: images/Scotch_terrier/
#  inflated: images/Scotch_terrier/n02097298_1007.jpg
#  inflated: images/Scotch_terrier/n02097298_10676.jpg
#  inflated: images/Scotch_terrier/n02097298_10965.jpg
#  inflated: images/Scotch_terrier/n02097298_11133.jpg
#  inflated: images/Scotch_terrier/n02097298_11346.jpg
#  inflated: images/Scotch_terrier/n02097298_1152.jpg
#  inflated: images/Scotch_terrier/n02097298_11702.jpg
#  inflated: images/Scotch_terrier/n02097298_12001.jpg
#  inflated: images/Scotch_terrier/n02097298_12063.jpg
#  inflated: images/Scotch_terrier/n02097298_1315.jpg
#  inflated: images/Scotch_terrier/n02097298_13186.jpg
#  inflated: images/Scotch_terrier/n02097298_1319.jpg
#  inflated: images/Scotch_terrier/n02097298_132.jpg
#  inflated: images/Scotch_terrier/n02097298_1327.jpg
#  inflated: images/Scotch_terrier/n02097298_13452.jpg
#  inflated: images/Scotch_terrier/n02097298_14007.jpg
#  inflated: images/Scotch_terrier/n02097298_14092.jpg
#  inflated: images/Scotch_terrier/n02097298_1410.jpg
#  inflated: images/Scotch_terrier/n02097298_1451.jpg
#  inflated: images/Scotch_terrier/n02097298_15004.jpg
#  inflated: images/Scotch_terrier/n02097298_15174.jpg
#  inflated: images/Scotch_terrier/n02097298_15251.jpg
#  inflated: images/Scotch_terrier/n02097298_161.jpg
#  inflated: images/Scotch_terrier/n02097298_16738.jpg
#  inflated: images/Scotch_terrier/n02097298_1790.jpg
#  inflated: images/Scotch_terrier/n02097298_1941.jpg
#  inflated: images/Scotch_terrier/n02097298_195.jpg
#  inflated: images/Scotch_terrier/n02097298_200.jpg
#  inflated: images/Scotch_terrier/n02097298_2083.jpg
#  inflated: images/Scotch_terrier/n02097298_2132.jpg
#  inflated: images/Scotch_terrier/n02097298_2135.jpg
#  inflated: images/Scotch_terrier/n02097298_2184.jpg
#  inflated: images/Scotch_terrier/n02097298_2227.jpg
#  inflated: images/Scotch_terrier/n02097298_2279.jpg
#  inflated: images/Scotch_terrier/n02097298_2287.jpg
#  inflated: images/Scotch_terrier/n02097298_231.jpg
#  inflated: images/Scotch_terrier/n02097298_2420.jpg
#  inflated: images/Scotch_terrier/n02097298_2443.jpg
#  inflated: images/Scotch_terrier/n02097298_2468.jpg
#  inflated: images/Scotch_terrier/n02097298_2492.jpg
#  inflated: images/Scotch_terrier/n02097298_2500.jpg
#  inflated: images/Scotch_terrier/n02097298_256.jpg
#  inflated: images/Scotch_terrier/n02097298_2583.jpg
#  inflated: images/Scotch_terrier/n02097298_2609.jpg
#  inflated: images/Scotch_terrier/n02097298_2671.jpg
#  inflated: images/Scotch_terrier/n02097298_2722.jpg
#  inflated: images/Scotch_terrier/n02097298_2792.jpg
#  inflated: images/Scotch_terrier/n02097298_2863.jpg
#  inflated: images/Scotch_terrier/n02097298_2868.jpg
#  inflated: images/Scotch_terrier/n02097298_2957.jpg
#  inflated: images/Scotch_terrier/n02097298_2976.jpg
#  inflated: images/Scotch_terrier/n02097298_2998.jpg
#  inflated: images/Scotch_terrier/n02097298_3238.jpg
#  inflated: images/Scotch_terrier/n02097298_3301.jpg
#  inflated: images/Scotch_terrier/n02097298_3342.jpg
#  inflated: images/Scotch_terrier/n02097298_344.jpg
#  inflated: images/Scotch_terrier/n02097298_3483.jpg
#  inflated: images/Scotch_terrier/n02097298_3516.jpg
#  inflated: images/Scotch_terrier/n02097298_3521.jpg
#  inflated: images/Scotch_terrier/n02097298_3522.jpg
#  inflated: images/Scotch_terrier/n02097298_3579.jpg
#  inflated: images/Scotch_terrier/n02097298_3589.jpg
#  inflated: images/Scotch_terrier/n02097298_3611.jpg
#  inflated: images/Scotch_terrier/n02097298_3618.jpg
#  inflated: images/Scotch_terrier/n02097298_3641.jpg
#  inflated: images/Scotch_terrier/n02097298_378.jpg
#  inflated: images/Scotch_terrier/n02097298_3780.jpg
#  inflated: images/Scotch_terrier/n02097298_39.jpg
#  inflated: images/Scotch_terrier/n02097298_3968.jpg
#  inflated: images/Scotch_terrier/n02097298_4020.jpg
#  inflated: images/Scotch_terrier/n02097298_4092.jpg
#  inflated: images/Scotch_terrier/n02097298_4126.jpg
#  inflated: images/Scotch_terrier/n02097298_4162.jpg
#  inflated: images/Scotch_terrier/n02097298_432.jpg
#  inflated: images/Scotch_terrier/n02097298_4485.jpg
#  inflated: images/Scotch_terrier/n02097298_4565.jpg
#  inflated: images/Scotch_terrier/n02097298_4628.jpg
#  inflated: images/Scotch_terrier/n02097298_4640.jpg
#  inflated: images/Scotch_terrier/n02097298_4701.jpg
#  inflated: images/Scotch_terrier/n02097298_4872.jpg
#  inflated: images/Scotch_terrier/n02097298_4882.jpg
#  inflated: images/Scotch_terrier/n02097298_4909.jpg
#  inflated: images/Scotch_terrier/n02097298_5074.jpg
#  inflated: images/Scotch_terrier/n02097298_508.jpg
#  inflated: images/Scotch_terrier/n02097298_6077.jpg
#  inflated: images/Scotch_terrier/n02097298_6084.jpg
#  inflated: images/Scotch_terrier/n02097298_6110.jpg
#  inflated: images/Scotch_terrier/n02097298_6261.jpg
#  inflated: images/Scotch_terrier/n02097298_6276.jpg
#  inflated: images/Scotch_terrier/n02097298_6313.jpg
#  inflated: images/Scotch_terrier/n02097298_6383.jpg
#  inflated: images/Scotch_terrier/n02097298_6462.jpg
#  inflated: images/Scotch_terrier/n02097298_6474.jpg
#  inflated: images/Scotch_terrier/n02097298_65.jpg
#  inflated: images/Scotch_terrier/n02097298_6681.jpg
#  inflated: images/Scotch_terrier/n02097298_6732.jpg
#  inflated: images/Scotch_terrier/n02097298_6740.jpg
#  inflated: images/Scotch_terrier/n02097298_6781.jpg
#  inflated: images/Scotch_terrier/n02097298_6863.jpg
#  inflated: images/Scotch_terrier/n02097298_6980.jpg
#  inflated: images/Scotch_terrier/n02097298_7115.jpg
#  inflated: images/Scotch_terrier/n02097298_7143.jpg
#  inflated: images/Scotch_terrier/n02097298_7262.jpg
#  inflated: images/Scotch_terrier/n02097298_7371.jpg
#  inflated: images/Scotch_terrier/n02097298_7442.jpg
#  inflated: images/Scotch_terrier/n02097298_7517.jpg
#  inflated: images/Scotch_terrier/n02097298_759.jpg
#  inflated: images/Scotch_terrier/n02097298_7629.jpg
#  inflated: images/Scotch_terrier/n02097298_7631.jpg
#  inflated: images/Scotch_terrier/n02097298_7639.jpg
#  inflated: images/Scotch_terrier/n02097298_7694.jpg
#  inflated: images/Scotch_terrier/n02097298_78.jpg
#  inflated: images/Scotch_terrier/n02097298_7835.jpg
#  inflated: images/Scotch_terrier/n02097298_7900.jpg
#  inflated: images/Scotch_terrier/n02097298_7932.jpg
#  inflated: images/Scotch_terrier/n02097298_8038.jpg
#  inflated: images/Scotch_terrier/n02097298_8046.jpg
#  inflated: images/Scotch_terrier/n02097298_809.jpg
#  inflated: images/Scotch_terrier/n02097298_8101.jpg
#  inflated: images/Scotch_terrier/n02097298_8146.jpg
# ...
#  inflated: images/whippet/n02091134_917.jpg
#  inflated: images/whippet/n02091134_9398.jpg
#  inflated: images/whippet/n02091134_9433.jpg
#  inflated: images/whippet/n02091134_9671.jpg
#  inflated: images/whippet/n02091134_969.jpg
#  inflated: images/whippet/n02091134_9740.jpg
#  inflated: images/whippet/n02091134_9793.jpg
#  inflated: images/whippet/n02091134_9806.jpg
#   created: images/wire/
#  inflated: images/wire/n02095314_1033.jpg
#  inflated: images/wire/n02095314_1043.jpg
#  inflated: images/wire/n02095314_105.jpg
#  inflated: images/wire/n02095314_1054.jpg
#  inflated: images/wire/n02095314_108.jpg
#  inflated: images/wire/n02095314_1080.jpg
#  inflated: images/wire/n02095314_1100.jpg
#  inflated: images/wire/n02095314_1104.jpg
#  inflated: images/wire/n02095314_1116.jpg
#  inflated: images/wire/n02095314_1177.jpg
#  inflated: images/wire/n02095314_1212.jpg
#  inflated: images/wire/n02095314_1268.jpg
#  inflated: images/wire/n02095314_1278.jpg
#  inflated: images/wire/n02095314_1282.jpg
#  inflated: images/wire/n02095314_138.jpg
#  inflated: images/wire/n02095314_1395.jpg
#  inflated: images/wire/n02095314_1407.jpg
#  inflated: images/wire/n02095314_1505.jpg
#  inflated: images/wire/n02095314_1533.jpg
#  inflated: images/wire/n02095314_1536.jpg
#  inflated: images/wire/n02095314_157.jpg
#  inflated: images/wire/n02095314_1577.jpg
#  inflated: images/wire/n02095314_1582.jpg
#  inflated: images/wire/n02095314_1583.jpg
#  inflated: images/wire/n02095314_1660.jpg
#  inflated: images/wire/n02095314_1665.jpg
#  inflated: images/wire/n02095314_1672.jpg
#  inflated: images/wire/n02095314_1704.jpg
#  inflated: images/wire/n02095314_1705.jpg
#  inflated: images/wire/n02095314_1717.jpg
#  inflated: images/wire/n02095314_1754.jpg
#  inflated: images/wire/n02095314_1772.jpg
#  inflated: images/wire/n02095314_1780.jpg
#  inflated: images/wire/n02095314_1782.jpg
#  inflated: images/wire/n02095314_1789.jpg
#  inflated: images/wire/n02095314_1814.jpg
#  inflated: images/wire/n02095314_1820.jpg
#  inflated: images/wire/n02095314_1829.jpg
#  inflated: images/wire/n02095314_1835.jpg
#  inflated: images/wire/n02095314_1866.jpg
#  inflated: images/wire/n02095314_188.jpg
#  inflated: images/wire/n02095314_1884.jpg
#  inflated: images/wire/n02095314_1894.jpg
#  inflated: images/wire/n02095314_1917.jpg
#  inflated: images/wire/n02095314_1945.jpg
#  inflated: images/wire/n02095314_1969.jpg
#  inflated: images/wire/n02095314_1974.jpg
#  inflated: images/wire/n02095314_1976.jpg
#  inflated: images/wire/n02095314_1997.jpg
#  inflated: images/wire/n02095314_2.jpg
#  inflated: images/wire/n02095314_2038.jpg
#  inflated: images/wire/n02095314_2059.jpg
#  inflated: images/wire/n02095314_2130.jpg
#  inflated: images/wire/n02095314_2139.jpg
#  inflated: images/wire/n02095314_2162.jpg
#  inflated: images/wire/n02095314_2196.jpg
#  inflated: images/wire/n02095314_2198.jpg
#  inflated: images/wire/n02095314_2205.jpg
#  inflated: images/wire/n02095314_2230.jpg
#  inflated: images/wire/n02095314_2247.jpg
#  inflated: images/wire/n02095314_2256.jpg
#  inflated: images/wire/n02095314_227.jpg
#  inflated: images/wire/n02095314_2308.jpg
#  inflated: images/wire/n02095314_2310.jpg
#  inflated: images/wire/n02095314_2314.jpg
#  inflated: images/wire/n02095314_2338.jpg
#  inflated: images/wire/n02095314_2354.jpg
#  inflated: images/wire/n02095314_2372.jpg
#  inflated: images/wire/n02095314_2421.jpg
#  inflated: images/wire/n02095314_2424.jpg
#  inflated: images/wire/n02095314_2460.jpg
#  inflated: images/wire/n02095314_2472.jpg
#  inflated: images/wire/n02095314_2519.jpg
#  inflated: images/wire/n02095314_252.jpg
#  inflated: images/wire/n02095314_2564.jpg
#  inflated: images/wire/n02095314_2609.jpg
#  inflated: images/wire/n02095314_261.jpg
#  inflated: images/wire/n02095314_2664.jpg
#  inflated: images/wire/n02095314_2683.jpg
#  inflated: images/wire/n02095314_2687.jpg
#  inflated: images/wire/n02095314_2699.jpg
#  inflated: images/wire/n02095314_2742.jpg
#  inflated: images/wire/n02095314_2754.jpg
#  inflated: images/wire/n02095314_2803.jpg
#  inflated: images/wire/n02095314_2827.jpg
#  inflated: images/wire/n02095314_2841.jpg
#  inflated: images/wire/n02095314_2863.jpg
#  inflated: images/wire/n02095314_2864.jpg
#  inflated: images/wire/n02095314_2876.jpg
#  inflated: images/wire/n02095314_289.jpg
#  inflated: images/wire/n02095314_2890.jpg
#  inflated: images/wire/n02095314_2904.jpg
#  inflated: images/wire/n02095314_293.jpg
#  inflated: images/wire/n02095314_2932.jpg
#  inflated: images/wire/n02095314_2964.jpg
#  inflated: images/wire/n02095314_3006.jpg
#  inflated: images/wire/n02095314_3039.jpg
#  inflated: images/wire/n02095314_3052.jpg
#  inflated: images/wire/n02095314_3054.jpg
#  inflated: images/wire/n02095314_3084.jpg
#  inflated: images/wire/n02095314_3091.jpg
#  inflated: images/wire/n02095314_3153.jpg
#  inflated: images/wire/n02095314_3166.jpg
#  inflated: images/wire/n02095314_318.jpg
#  inflated: images/wire/n02095314_3185.jpg
#  inflated: images/wire/n02095314_3189.jpg
#  inflated: images/wire/n02095314_3217.jpg
#  inflated: images/wire/n02095314_3227.jpg
#  inflated: images/wire/n02095314_3240.jpg
#  inflated: images/wire/n02095314_3242.jpg
#  inflated: images/wire/n02095314_3246.jpg
#  inflated: images/wire/n02095314_3295.jpg
#  inflated: images/wire/n02095314_3299.jpg
#  inflated: images/wire/n02095314_3316.jpg
#  inflated: images/wire/n02095314_3321.jpg
#  inflated: images/wire/n02095314_3343.jpg
#  inflated: images/wire/n02095314_3364.jpg
#  inflated: images/wire/n02095314_3372.jpg
#  inflated: images/wire/n02095314_3395.jpg
#  inflated: images/wire/n02095314_3451.jpg
#  inflated: images/wire/n02095314_3472.jpg
#  inflated: images/wire/n02095314_3483.jpg
#  inflated: images/wire/n02095314_3495.jpg
#  inflated: images/wire/n02095314_3509.jpg
#  inflated: images/wire/n02095314_3512.jpg
#  inflated: images/wire/n02095314_3527.jpg
#  inflated: images/wire/n02095314_367.jpg
#  inflated: images/wire/n02095314_397.jpg
#  inflated: images/wire/n02095314_398.jpg
#  inflated: images/wire/n02095314_401.jpg
#  inflated: images/wire/n02095314_448.jpg
#  inflated: images/wire/n02095314_464.jpg
#  inflated: images/wire/n02095314_481.jpg
#  inflated: images/wire/n02095314_493.jpg
#  inflated: images/wire/n02095314_504.jpg
#  inflated: images/wire/n02095314_547.jpg
#  inflated: images/wire/n02095314_550.jpg
#  inflated: images/wire/n02095314_591.jpg
#  inflated: images/wire/n02095314_594.jpg
#  inflated: images/wire/n02095314_613.jpg
#  inflated: images/wire/n02095314_651.jpg
#  inflated: images/wire/n02095314_662.jpg
#  inflated: images/wire/n02095314_663.jpg
#  inflated: images/wire/n02095314_669.jpg
#  inflated: images/wire/n02095314_691.jpg
#  inflated: images/wire/n02095314_725.jpg
#  inflated: images/wire/n02095314_740.jpg
#  inflated: images/wire/n02095314_777.jpg
#  inflated: images/wire/n02095314_792.jpg
#  inflated: images/wire/n02095314_80.jpg
#  inflated: images/wire/n02095314_807.jpg
#  inflated: images/wire/n02095314_928.jpg
#  inflated: images/wire/n02095314_942.jpg
#  inflated: images/wire/n02095314_956.jpg
#  inflated: images/wire/n02095314_963.jpg
#  inflated: images/wire/n02095314_969.jpg
#  inflated: images/wire/n02095314_996.jpg
#   created: images/Yorkshire_terrier/
#  inflated: images/Yorkshire_terrier/n02094433_10123.jpg
#  inflated: images/Yorkshire_terrier/n02094433_10126.jpg
#  inflated: images/Yorkshire_terrier/n02094433_10184.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1030.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1177.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1210.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1211.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1219.jpg
#  inflated: images/Yorkshire_terrier/n02094433_126.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1269.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1301.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1312.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1324.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1376.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1483.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1490.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1525.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1539.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1634.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1765.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1770.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1772.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1824.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1849.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1868.jpg
#  inflated: images/Yorkshire_terrier/n02094433_1869.jpg
#  inflated: images/Yorkshire_terrier/n02094433_194.jpg
#  inflated: images/Yorkshire_terrier/n02094433_199.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2006.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2022.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2041.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2053.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2105.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2114.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2115.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2125.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2127.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2197.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2223.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2229.jpg
#  inflated: images/Yorkshire_terrier/n02094433_225.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2266.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2328.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2340.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2349.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2375.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2401.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2417.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2457.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2474.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2483.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2519.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2537.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2564.jpg
#  inflated: images/Yorkshire_terrier/n02094433_259.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2596.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2609.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2643.jpg
#  inflated: images/Yorkshire_terrier/n02094433_266.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2678.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2685.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2740.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2748.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2759.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2776.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2782.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2824.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2838.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2882.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2901.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2903.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2919.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2973.jpg
#  inflated: images/Yorkshire_terrier/n02094433_2987.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3010.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3043.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3088.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3117.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3192.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3198.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3202.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3279.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3296.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3335.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3392.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3400.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3431.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3480.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3526.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3560.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3604.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3613.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3640.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3642.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3655.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3704.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3766.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3812.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3848.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3878.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3881.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3905.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3947.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3983.jpg
#  inflated: images/Yorkshire_terrier/n02094433_3999.jpg
#  inflated: images/Yorkshire_terrier/n02094433_4005.jpg
#  inflated: images/Yorkshire_terrier/n02094433_4028.jpg
#  inflated: images/Yorkshire_terrier/n02094433_4091.jpg
#  inflated: images/Yorkshire_terrier/n02094433_4167.jpg
#  inflated: images/Yorkshire_terrier/n02094433_4181.jpg
#  inflated: images/Yorkshire_terrier/n02094433_4198.jpg
#  inflated: images/Yorkshire_terrier/n02094433_4214.jpg
#  inflated: images/Yorkshire_terrier/n02094433_4248.jpg
#  inflated: images/Yorkshire_terrier/n02094433_4399.jpg
#  inflated: images/Yorkshire_terrier/n02094433_4588.jpg
#  inflated: images/Yorkshire_terrier/n02094433_4624.jpg
#  inflated: images/Yorkshire_terrier/n02094433_4710.jpg
#  inflated: images/Yorkshire_terrier/n02094433_478.jpg
#  inflated: images/Yorkshire_terrier/n02094433_4916.jpg
#  inflated: images/Yorkshire_terrier/n02094433_4990.jpg
#  inflated: images/Yorkshire_terrier/n02094433_515.jpg
#  inflated: images/Yorkshire_terrier/n02094433_5155.jpg
#  inflated: images/Yorkshire_terrier/n02094433_5176.jpg
#  inflated: images/Yorkshire_terrier/n02094433_5350.jpg
#  inflated: images/Yorkshire_terrier/n02094433_5356.jpg
#  inflated: images/Yorkshire_terrier/n02094433_5384.jpg
#  inflated: images/Yorkshire_terrier/n02094433_540.jpg
#  inflated: images/Yorkshire_terrier/n02094433_5500.jpg
#  inflated: images/Yorkshire_terrier/n02094433_5868.jpg
#  inflated: images/Yorkshire_terrier/n02094433_621.jpg
#  inflated: images/Yorkshire_terrier/n02094433_6258.jpg
#  inflated: images/Yorkshire_terrier/n02094433_63.jpg
#  inflated: images/Yorkshire_terrier/n02094433_6328.jpg
#  inflated: images/Yorkshire_terrier/n02094433_6338.jpg
#  inflated: images/Yorkshire_terrier/n02094433_6672.jpg
#  inflated: images/Yorkshire_terrier/n02094433_668.jpg
#  inflated: images/Yorkshire_terrier/n02094433_701.jpg
#  inflated: images/Yorkshire_terrier/n02094433_708.jpg
#  inflated: images/Yorkshire_terrier/n02094433_716.jpg
#  inflated: images/Yorkshire_terrier/n02094433_719.jpg
#  inflated: images/Yorkshire_terrier/n02094433_7191.jpg
#  inflated: images/Yorkshire_terrier/n02094433_730.jpg
#  inflated: images/Yorkshire_terrier/n02094433_7394.jpg
#  inflated: images/Yorkshire_terrier/n02094433_7445.jpg
#  inflated: images/Yorkshire_terrier/n02094433_745.jpg
#  inflated: images/Yorkshire_terrier/n02094433_7464.jpg
#  inflated: images/Yorkshire_terrier/n02094433_7495.jpg
#  inflated: images/Yorkshire_terrier/n02094433_7702.jpg
#  inflated: images/Yorkshire_terrier/n02094433_7827.jpg
#  inflated: images/Yorkshire_terrier/n02094433_785.jpg
#  inflated: images/Yorkshire_terrier/n02094433_795.jpg
#  inflated: images/Yorkshire_terrier/n02094433_800.jpg
#  inflated: images/Yorkshire_terrier/n02094433_8419.jpg
#  inflated: images/Yorkshire_terrier/n02094433_8535.jpg
#  inflated: images/Yorkshire_terrier/n02094433_8580.jpg
#  inflated: images/Yorkshire_terrier/n02094433_8669.jpg
#  inflated: images/Yorkshire_terrier/n02094433_889.jpg
#  inflated: images/Yorkshire_terrier/n02094433_8977.jpg
#  inflated: images/Yorkshire_terrier/n02094433_923.jpg
#  inflated: images/Yorkshire_terrier/n02094433_96.jpg
#  inflated: images/Yorkshire_terrier/n02094433_9618.jpg
#  inflated: images/Yorkshire_terrier/n02094433_962.jpg
#  inflated: images/Yorkshire_terrier/n02094433_967.jpg
#  inflated: images/Yorkshire_terrier/n02094433_9739.jpg

# %%
from __future__ import print_function

import os
import argparse

import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib import offsetbox
from mpl_toolkits.axes_grid1 import ImageGrid
from scipy.optimize import linear_sum_assignment as linear_assignment_
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from itertools import chain

import torch
import torch.backends.cudnn as cudnn
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import ImageFolder
import torch.optim as optim
import torch.nn as nn
import torchvision

# Get data
from PIL import Image
import os.path
import shutil
import requests
import zipfile

from pathlib import Path
import glob
from sklearn.model_selection import train_test_split

# %%
from torch.autograd import Variable
import torch.nn.functional as F
# can use the below import should you choose to initialize the weights of your Net
import torch.nn.init as I

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:",device)
# Out:
# device: cuda

# %%
from os.path import join, expanduser

root = expanduser("")
imagesets = join(root, 'DATASETS', 'IMAGE')
models = join(root, 'Models')
plots = join(root, 'Plots')

# %%
import argparse # Importing the argparse module

def parse_args():
    """Parses command line arguments."""
    parser = argparse.ArgumentParser(description='PyTorch DML Training')
    parser.add_argument('--batch_size', help='Batch_size', default=64, type=int)
    parser.add_argument('--n_epochs', help='Number of Epochs', default=30, type=int)
    parser.add_argument('--learning_rate', help='Learning Rate', default=0.01, type=float)
    parser.add_argument('--saved_epoch', help='epoch of saved model', default=None, type=int)
    parser.add_argument('--run_id', help='Used to help identify artifacts', default=0, type=int)

    # Change: Removing the SystemExit call
    args, unknown = parser.parse_known_args()  # Parse arguments
    if unknown:  # If there are unknown arguments
        print(f"Warning: Ignoring unknown arguments: {unknown}")  # Print a warning

    return args

# %%
def train_model(batch_size, n_epochs, learning_rate,
                saved_epoch,
                run_id="def",
                save_every=1000, save_path=models,
                plot_every=500, plot_path=plots):
    # Setup save directories
    if save_path:
        save_path = os.path.join(save_path, f"run_{run_id}")
        os.makedirs(save_path, exist_ok=True)
    if plot_path:
        plot_path = os.path.join(plot_path, f"run_{run_id}")
        os.makedirs(plot_path, exist_ok=True)

    # Load network and use GPU
    net = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained = True)

    # Get the number of input features for the classifier
    in_features = net.roi_heads.box_predictor.cls_score.in_features
    # Replace the pre-trained head with a new one (Note: `box_predictor` can be `FasterRCNNPredictor`)
    net.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features, 120)

    if torch.cuda.is_available():
        net = net.cuda()
        cudnn.benchmark = True
    else:
        print("No GPU available")

    # Setup path to data folder
    image_path = Path("/content/classified_images/")

    # if the image folder doesn't exist, download it and prepare it...
    if image_path.is_dir():
        print(f"{image_path} directory exists.")
    else:
        print(f"Did not find {image_path} directory, creating one...")
        image_path.mkdir(parents=True, exist_ok=True)

    # Setup Dirs
    train_dir = image_path / "train"
    valid_dir = image_path / "valid"
    test_dir = image_path / "test"
    train_dir.mkdir(parents=True, exist_ok=True)
    valid_dir.mkdir(parents=True, exist_ok=True)
    test_dir.mkdir(parents=True, exist_ok=True)

    # Check if directories are populated with valid images
    def check_image_directories(root_dir):
        """Checks if image directories are populated and contain jpg formats."""
        for subdir in ['train', 'valid', 'test']:
            dir_path = os.path.join(root_dir, subdir)
            if not os.path.exists(dir_path):
                print(f"Directory {dir_path} does not exist. Creating it...")
                os.makedirs(dir_path)  # Create directory if it doesn't exist
                return False  # Return False to indicate directory was created
            if not os.listdir(dir_path):
                print(f"Directory {dir_path} is empty.")
                return False
            # Check if any images have valid extensions
            has_valid_images = glob.glob(os.path.join(dir_path,'**/*.jpg'), recursive=True)
            if not has_valid_images:
                print(f"Directory {dir_path} does not contain valid image files with supported extensions.")
                return False
            for item in has_valid_images:
                if os.path.isfile(item) and not item.lower().endswith('.jpg'):
                    print(f"File {item} has an unsupported format.")
                    return False
        print("Image directories are populated and contain supported image formats.")
        return True

    if not check_image_directories(str(image_path)):
        print("Please populate the image directories with valid images before running the training.")
        # Create symbolic links to example images if the train directory is empty
        if not os.listdir(train_dir):
            print(f"Creating symbolic links to example images in {train_dir}")
            example_images = [f for f in os.listdir(image_path) if f.endswith(('.jpg', '.jpeg', '.png'))]
            # Check if example images exist before creating symlinks
            if example_images:
                for image in example_images:
                    source_path = os.path.join(image_path, image)
                    destination_path = os.path.join(train_dir, image)

                    # Handle existing symlinks
                    if os.path.islink(destination_path):
                        os.unlink(destination_path)

                    # Create the symbolic link
                    os.symlink(source_path, destination_path)

                print(f"Symbolic links created. Please replace them with your actual training images.")
            else:
                print("No example images found in the root directory.")
        return  # Exit the function to avoid further errors

    # transforms for images
    transforms = torchvision.transforms.Compose([
        torchvision.transforms.Resize(256),
        torchvision.transforms.CenterCrop(224),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.RandomHorizontalFlip(p = 0.5)
    ])

    # Load dataset
    train_data = ImageFolder(root=str(train_dir), transform=transforms)
    valid_data = ImageFolder(root=str(valid_dir), transform=transforms)
    test_data = ImageFolder(root=str(test_dir), transform=transforms)

    classes = train_data.classes
    print("Classes:", classes)
    print("Training data shape:", len(train_data))
    print("valid data shape:", len(valid_data))
    print("Testing data shape:", len(test_data))

    if len(train_data) == 0 or len(valid_data) == 0 or len(test_data) == 0:
        raise ValueError("One or more datasets are empty. Check your image directories.")

    #train_y, test_y = utils.get_labels(train_data), utils.get_labels(test_data)
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_data, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

    # obtain one batch of training images
    dataiter = iter(train_loader)
    images, labels = next(dataiter)
    images = np.swapaxes(np.swapaxes(images.numpy(), 1, 2), 2, 3)

    # plot the images in the batch, along with the corresponding labels
    fig = plt.figure(figsize=(batch_size/4+5, batch_size/4+5))
    for idx in np.arange(batch_size):
        ax = fig.add_subplot(batch_size//8, 8, idx+1, xticks=[], yticks=[])
        ax.imshow(images[idx])
        ax.set_title(classes[labels[idx]], {'fontsize': batch_size/5}, pad=0.4)
    plt.tight_layout(pad=1, w_pad=0, h_pad=0)
    if plot_path:
        plt.savefig(os.path.join(plot_path, "Initial_Visualization"))
    else:
        plt.show()
    plt.clf()

    # cross entropy loss combines softmax and nn.NLLLoss() in one single class.
    criterion = nn.NLLLoss()

    # stochastic gradient descent with a small learning rate
    optimizer = optim.SGD(net.parameters(), lr=learning_rate)

    # ToDo: Add to utils
    # Calculate accuracy before training
    correct = 0
    total = 0

    # Iterate through test dataset
    for images, labels in test_loader:
        images, labels = images.cuda(), labels.cuda()

        # set the model to evaluation mode before inference
        net.eval()

        # forward pass to get outputs
        # the outputs are a series of class scores
        # Since we are in evaluation mode, we don't need targets
        with torch.no_grad():  # Disable gradient calculation during inference
            outputs = net(images)

        # Set the model back to training mode
        net.train()

        # get the predicted class from the maximum value in the output-list of class scores
        _, predicted = torch.max(outputs.data, 1)

        # count up total number of correct labels
        # for which the predicted and true labels are equal
        total += labels.size(0)
        correct += (predicted == labels).sum()

    # calculate the accuracy
    # to convert `correct` from a Tensor into a scalar, use .item()
    accuracy = 100.0 * correct.item() / total

    print('Accuracy before training: ', accuracy)

    # Within the `train` function:
    def train(n_epochs):
        net.train()
        loss_over_time = [] # to track the loss as the network trains

        for epoch in range(n_epochs):  # loop over the dataset multiple times
            output_epoch = epoch + saved_epoch
            running_loss = 0.0

            for batch_i, data in enumerate(train_loader):
                # get the input images and their corresponding labels
                inputs, labels = data
                inputs, labels = inputs.cuda(), labels.cuda()

                # zero the parameter (weight) gradients
                optimizer.zero_grad()

                # forward pass to get outputs
                outputs = net(inputs, labels)

                # calculate the loss
                # loss = criterion(outputs, labels)
                loss = sum(loss for loss in outputs.values())

                # backward pass to calculate the parameter gradients
                loss.backward()

                # update the parameters
                optimizer.step()

                # print loss statistics
                # to convert loss into a scalar and add it to running_loss, we use .item()
                running_loss += loss.item()

                if batch_i % 45 == 44:    # print every 45 batches
                    avg_loss = running_loss/45
                    # record and print the avg loss over the 100 batches
                    loss_over_time.append(avg_loss)
                    print(f'Epoch: {output_epoch + 1}, Batch: {batch_i+1}, Avg. Loss: {avg_loss}')
                    running_loss = 0.0
            if output_epoch % 100 == 99: # save every 100 epochs
                torch.save(net.state_dict(), f'saved_models/Net2_{output_epoch + 1}.pt')

        print('Finished Training')
        return loss_over_time

    if saved_epoch:
        net.load_state_dict(torch.load(f'saved_models/Net2_{saved_epoch}.pt'))

    # call train and record the loss over time
    training_loss = train(n_epochs)

    # visualize the loss as the network trained
    fig = plt.figure()
    plt.plot(45*np.arange(len(training_loss)), training_loss)
    plt.rc('xtick', labelsize=12)
    plt.rc('ytick', labelsize=12)
    plt.xlabel('Number of Batches', fontsize=12)
    plt.ylabel('loss', fontsize=12)
    plt.ylim(0, 5.5) # consistent scale
    plt.tight_layout()
    if plot_path:
        plt.savefig(os.path.join(plot_path, "Loss_Over_Time"))
        print("saved")
    else:
        plt.show()
    plt.clf()

    # initialize tensor and lists to monitor test loss and accuracy
    test_loss = torch.zeros(1).cuda()
    class_correct = list(0. for i in range(len(classes)))
    class_total = list(0. for i in range(len(classes)))

    # set the module to evaluation mode
    # used to turn off layers that are only useful for training
    # like dropout and batch_norm


    for images, labels in test_loader:

        # get the input images and their corresponding labels
        images, labels = images.cuda(), labels.cuda()

        net.eval()
        # forward pass to get outputs
        with torch.no_grad():
            outputs = net(images)

        # update average test loss
        test_loss += criterion(outputs, labels).item()
        # Get the predicted class
        # Extract the classification scores and apply torch.max
        scores = outputs[0]['scores']  # Assuming outputs[0] contains detection results
        _, predicted = torch.max(scores, 1)
        # count up total number of correct labels
        # for which the predicted and true labels are equal
        total += labels.size(0)
        correct += (predicted == labels).sum()
        # calculate the loss
        # calculate test accuracy for *each* object class
        # we get the scalar value of correct items for a class, by calling `correct[i].item()`
        for l, c in zip(labels.data, correct):
            class_correct[l] += c.item()
            class_total[l] += 1
    accuracy = 100.0 * correct.item() / total



        # compare predictions to true label
        # this creates a `correct` Tensor that holds the number of correctly classified images in a batch




    print(f'Test Loss: {test_loss.cpu().numpy()[0]:.6f}\n')

    for i in range(len(classes)):
        if class_total[i] > 0:
            print('Test Accuracy of %30s: %2d%% (%2d/%2d)' % (
                classes[i], 100 * class_correct[i] / class_total[i],
                np.sum(class_correct[i]), np.sum(class_total[i])))
        else:
            print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))


    print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
        100. * np.sum(class_correct) / np.sum(class_total),
        np.sum(class_correct), np.sum(class_total)))

    # Visualize Sample Results (Runs until a batch contains a )
    # plot the images in the batch, along with predicted and true labels
    fig = plt.figure(figsize=(batch_size/4+5, batch_size/4+5))
    misclassification_found = False
    while(not misclassification_found):
        fig.clf()
        # obtain one batch of test images
        dataiter = iter(test_loader)
        images, labels = dataiter.next()
        images, labels = images.cuda(), labels.cuda()
        # get predictions
        preds = np.squeeze(net(images).data.max(1, keepdim=True)[1].cpu().numpy())
        images = np.swapaxes(np.swapaxes(images.cpu().numpy(), 1, 2), 2, 3)
        for idx in np.arange(batch_size):
            ax = fig.add_subplot(batch_size/8, 8, idx+1, xticks=[], yticks=[])
            ax.imshow(images[idx])
            if preds[idx]==labels[idx]:
                ax.set_title(f"{classes[preds[idx]], classes[labels[idx]]}", color="green")
            else:
                ax.set_title(f"({classes[labels[idx]]})\n{classes[preds[idx]]}", color="red", pad=.4)
                misclassification_found = True
    if plot_path:
        plt.savefig(os.path.join(plot_path, "Results Visualization"))
    else:
        plt.show()
    plt.clf()

# %%
def main():
    args = parse_args()
    train_model(batch_size=32,
                n_epochs=20,
                learning_rate = 0.001,
                saved_epoch = 5,
                run_id=args.run_id)
    print("ok")

# %%
import os

def check_image_directories(root_dir):
    """Checks if image directories are populated and contain supported image formats."""

    supported_extensions = ('.jpg', '.jpeg', '.png', '.ppm', '.bmp', '.pgm', '.tif', '.tiff', '.webp')

    for subdir in ['train', 'valid', 'test']:
        dir_path = os.path.join(root_dir, subdir)
        if not os.path.exists(dir_path):
            print(f"Directory {dir_path} does not exist.")
            return False

        if not os.listdir(dir_path):
            print(f"Directory {dir_path} is empty.")
            return False

        for item in os.listdir(dir_path):
            item_path = os.path.join(dir_path, item)
            if os.path.isfile(item_path) and not item_path.lower().endswith(supported_extensions):
                print(f"File {item_path} has an unsupported format.")
                return False

    print("Image directories are populated and contain supported image formats.")
    return True

# Call the function to check your image directories
root_dir = './classified_images/'  # Replace with your image directory path
print(check_image_directories(root_dir))
# Out:
# Image directories are populated and contain supported image formats.
# True

# %%
if __name__ == "__main__":
    main()
# Out:
# Warning: Ignoring unknown arguments: ['-f', '/root/.local/share/jupyter/runtime/kernel-688661d0-0910-4ebe-b62f-6c472bd84f0b.json']
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /content/classified_images directory exists.
# Image directories are populated and contain supported image formats.
# Classes: ['Afghan_hound', 'African_hunting_dog', 'Airedale', 'American_Staffordshire_terrier', 'Appenzeller', 'Australian_terrier', 'Bedlington_terrier', 'Bernese_mountain_dog', 'Blenheim_spaniel', 'Border_collie', 'Border_terrier', 'Boston_bull', 'Bouvier_des_Flandres', 'Brabancon_griffon', 'Brittany_spaniel', 'Cardigan', 'Chesapeake_Bay_retriever', 'Chihuahua', 'Dandie_Dinmont', 'Doberman', 'English_foxhound', 'English_setter', 'English_springer', 'EntleBucher', 'Eskimo_dog', 'French_bulldog', 'German_shepherd', 'German_short', 'Gordon_setter', 'Great_Dane', 'Great_Pyrenees', 'Greater_Swiss_Mountain_dog', 'Ibizan_hound', 'Irish_setter', 'Irish_terrier', 'Irish_water_spaniel', 'Irish_wolfhound', 'Italian_greyhound', 'Japanese_spaniel', 'Kerry_blue_terrier', 'Labrador_retriever', 'Lakeland_terrier', 'Leonberg', 'Lhasa', 'Maltese_dog', 'Mexican_hairless', 'Newfoundland', 'Norfolk_terrier', 'Norwegian_elkhound', 'Norwich_terrier', 'Old_English_sheepdog', 'Pekinese', 'Pembroke', 'Pomeranian', 'Rhodesian_ridgeback', 'Rottweiler', 'Saint_Bernard', 'Saluki', 'Samoyed', 'Scotch_terrier', 'Scottish_deerhound', 'Sealyham_terrier', 'Shetland_sheepdog', 'Shih', 'Siberian_husky', 'Staffordshire_bullterrier', 'Sussex_spaniel', 'Tibetan_mastiff', 'Tibetan_terrier', 'Walker_hound', 'Weimaraner', 'Welsh_springer_spaniel', 'West_Highland_white_terrier', 'Yorkshire_terrier', 'affenpinscher', 'basenji', 'basset', 'beagle', 'black', 'bloodhound', 'bluetick', 'borzoi', 'boxer', 'briard', 'bull_mastiff', 'cairn', 'chow', 'clumber', 'cocker_spaniel', 'collie', 'curly', 'dhole', 'dingo', 'flat', 'giant_schnauzer', 'golden_retriever', 'groenendael', 'keeshond', 'kelpie', 'komondor', 'kuvasz', 'malamute', 'malinois', 'miniature_pinscher', 'miniature_poodle', 'miniature_schnauzer', 'otterhound', 'papillon', 'pug', 'redbone', 'schipperke', 'silky_terrier', 'soft', 'standard_poodle', 'standard_schnauzer', 'toy_poodle', 'toy_terrier', 'vizsla', 'whippet', 'wire']
# Training data shape: 16418
# valid data shape: 2009
# Testing data shape: 2153
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-972361fa1b80> in <cell line: 1>()
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# <ipython-input-23-79dccc117ff3> in main()
#       1 def main():
#       2     args = parse_args()
# ----> 3     train_model(batch_size=32,
#       4                 n_epochs=20,
#       5                 learning_rate = 0.001,
#
# <ipython-input-25-bf018e43b31a> in train_model(batch_size, n_epochs, learning_rate, saved_epoch, run_id, save_every, save_path, plot_every, plot_path)
#     165
#     166         # get the predicted class from the maximum value in the output-list of class scores
# --> 167         _, predicted = torch.max(outputs.data, 1)
#     168
#     169         # count up total number of correct labels
#
# AttributeError: 'list' object has no attribute 'data'
